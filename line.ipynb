# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
np.set_printoptions(linewidth=200)   # print full array/matrix

original_image = mpimg.imread('images/x.png')
original_grey = np.dot(original_image[..., :3], [0.2989, 0.5870, 0.1140])
image = np.dot(original_image[..., :3], [0.2989, 0.5870, 0.1140])

plt.figure(figsize=(6, 6))
plt.imshow(original_grey, cmap='gray', vmin=0, vmax=1)
plt.axis('off')
plt.show()

print(f'shape: {original_grey.shape}')
print(f'min: {round(original_grey.min(), 4)}')
print(f'max: {round(original_grey.max(), 4)}')
# Out:
# shape: (800, 800)
# min: 0.0
# max: 0.8976

# %% [markdown]
# #### Convertir a blanco y negro

# %%
# valor más repetido
def mas_repetido(image, value=None, delta=None):   # value: 'min' | 'max'
    minimo = image.min()
    maximo = image.max()
    
    if value == None:
        valores, conteos = np.unique(image, return_counts=True)
        rep = valores[np.argmax(conteos)]
        return rep
    elif value == 'min':   # min: mas oscuros
        rango_min = minimo + delta
        rango = image[(image >= minimo) & (image <= rango_min)]
        valores, conteos = np.unique(rango, return_counts=True)
        rep = valores[np.argmax(conteos)]
        return rep
    elif value == 'max':   # min: mas claros
        rango_max = maximo - delta
        rango = image[(image <= maximo) & (image >= rango_max)]
        valores, conteos = np.unique(rango, return_counts=True)
        rep = valores[np.argmax(conteos)]
        return rep
    
# Detectar si es similar a rep
def rep_to_color(valor, rep, delta):
    if abs(valor - rep) <= delta: return True
    else: return False

# cambiar color mas oscuro y mas repetido (texto) a negro
def toBlack(image, delta1, delta2):
    rep = mas_repetido(image, 'min', delta1)
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            if rep_to_color(image[i, j], rep, delta2):
                image[i, j] = 0
    return image

# suponiendo que todos los oscuros ya se convirtieron a 0, convertir todo el resto en 1
def toWhite(image):
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            if image[i, j] != 0:
                image[i, j] = 1
    return image

# definir tono actual
def tono(valor, delta, min_rep, max_rep):
    if abs(valor - min_rep) <= delta: return 0
    elif abs(valor - max_rep) <= delta: return 1

# %%
image = toBlack(image, 0.05, 0.4)
image = toWhite(image)

plt.figure(figsize=(6, 6))
plt.imshow(image, cmap='gray',vmin=0, vmax=1)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Mejorar imperfecciones: square-radius code

# %%
def vecinos(image, coord, R):
    vecinos = []
    i = coord[0]
    j = coord[1]
    down_lim = image.shape[0] - 1
    left_lim = image.shape[1] - 1
    
    # filas arriba
    for r in range(R, 0, -1):
        if i - r >= 0:
            for rr in range (R, 0, -1):
                if j - rr >= 0:
                    vecinos.append(image[i-r, j-rr])
            vecinos.append(image[i-r, j])
            for rr in range(1, R+1):
                if j + rr <= left_lim:
                    vecinos.append(image[i-r, j+rr])
    
    # misma fila                
    for r in range(R, 0, -1):
        if j - r >= 0:
            vecinos.append(image[i, j-r])
    for r in range(1, R+1):
        if j + r <= left_lim:
            vecinos.append(image[i, j+r])
            
    # filas abajo
    for r in range(1, R+1):
        if i + r <= down_lim:
            for rr in range (R, 0, -1):
                if j - rr >= 0:
                    vecinos.append(image[i+r, j-rr])
            vecinos.append(image[i+r, j])
            for rr in range(1, R+1):
                if j + rr <= left_lim:
                    vecinos.append(image[i+r, j+rr])
                
    return np.array(vecinos)

# %%
def porcentaje_black_vecinos(image, r, p):
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            vecinos_lst = vecinos(image, (i, j), r)
            if image[i, j] == 1:
                porcentaje = len(vecinos_lst[vecinos_lst == 0]) / len(vecinos_lst)
                if porcentaje >= p:
                    image[i, j] = 0
    return image

def porcentaje_white_vecinos(image, r, p):
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            vecinos_lst = vecinos(image, (i, j), r)
            if image[i, j] == 0:
                porcentaje = len(vecinos_lst[vecinos_lst == 1]) / len(vecinos_lst)
                if porcentaje >= p:
                    image[i, j] = 1
    return image

# %%
image = porcentaje_black_vecinos(image, 6, 0.51) # 6
image = porcentaje_white_vecinos(image, 4, 0.51) # 4

plt.figure(figsize=(6, 6))
plt.imshow(image, cmap='gray',vmin=0, vmax=1)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Bordes

# %%
border_mask = np.zeros(image.shape)

min_rep = mas_repetido(image, 'min', 0.1)
max_rep = mas_repetido(image, 'max', 0.1)

delta = 0.05
delta1 = 0.05

# izquierda -> derecha | arriba -> abajo
for i in range(image.shape[0]):
    for j in range(image.shape[1] - 1):
        tono_actual = tono(image[i,j], delta1, min_rep, max_rep)
        if abs(image[i,j] - image[i,j+1]) > delta:
            if tono_actual == 1:
                border_mask[i,j+1] = 1
            elif tono_actual == 0:
                border_mask[i,j] = 1
                
# arriba -> abajo | izquierda -> derecha
for j in range(image.shape[1]):
    for i in range(image.shape[0] - 1):
        tono_actual = tono(image[i,j], delta1, min_rep, max_rep)
        if abs(image[i,j] - image[i+1,j]) > delta:
            if tono_actual == 1:
                border_mask[i+1,j] = 1
            elif tono_actual == 0:
                border_mask[i,j] = 1
                
plt.figure(figsize=(6, 6))
plt.imshow(border_mask, cmap='gray',vmin=0, vmax=1)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Línea entre bordes

# %%
for i in range(image.shape[0]):
    inBlack = []
    status = 0   # 1: in black, 0: not in black
    for j in range(image.shape[1]):
        if image[i][j] == 0:
            status = 1
        elif image[i][j] == 1:
            status = 0
        if status == 1:
            pass

# %%
# guardar en border_coords listas con las coordenadas de cada fila que donde el valor sea 1
border_coords = []
for i in range(border_mask.shape[0]):
    row_coords = []
    for j in range(border_mask.shape[1]):
        if border_mask[i,j] == 1:
            row_coords.append((i,j))
    if len(row_coords) != 0:
        border_coords.append(row_coords)
        
border_coords[0:5]
# Out:
# [[(310, 358), (310, 359), (310, 360), (310, 361), (310, 362)],
#  [(311, 354), (311, 355), (311, 356), (311, 357), (311, 363)],
#  [(312, 353), (312, 364)],
#  [(313, 351), (313, 352), (313, 365)],
#  [(314, 350), (314, 366)]]

# %% [markdown]
# **Idea.** *Paso 1:* si en cada fila los valores de j están suficientemente cerca (definir un $\Delta_1$) entre sí, buscar el punto medio entre ellos y colocoar ahí un punto. *Paso 2:* si en la misma fila dos valores de j de coordenadas consecutivas están suficientemente distanciados (definir un $\Delta_2$) entre sí, entonces eso indica que son de bordes distintos. Por lo tanto, hacer el *Paso 1* hsta que la diferencia entre el j de una coordenada y la siguiente sea suficientemente grande (mayor a $\Delta_2$) y desde esa siguiente coordenada volver a repetir el *Paso 1*.
